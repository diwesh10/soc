# %%
import deeplake
ds = deeplake.load('hub://activeloop/fer2013-train')
# Out:
# D:\anaconda\Lib\site-packages\deeplake\util\check_latest_version.py:32: UserWarning: A newer version of deeplake (3.9.18) is available. It's recommended that you update to the latest version using `pip install -U deeplake`.
#   warnings.warn(
# \
# Opening dataset in read-only mode as you don't have write permissions.
# \
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/fer2013-train
# -
# hub://activeloop/fer2013-train loaded successfully.

# %%
IMG_HEIGHT=48 
IMG_WIDTH = 48
batch_size=64

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
import os
from matplotlib import pyplot as plt
import numpy as np

# %%
train_data_dir='D:/jv/train'
validation_data_dir='D:/jv/test'

# %%
train_datagen = ImageDataGenerator(
					rescale=1./255,
					rotation_range=30,
					shear_range=0.3,
					zoom_range=0.3,
					horizontal_flip=True,
					fill_mode='nearest')

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
					train_data_dir,
					color_mode='grayscale',
					target_size=(IMG_HEIGHT, IMG_WIDTH),
					batch_size=batch_size,
					class_mode='categorical',
					shuffle=True)
# Out:
# Found 28709 images belonging to 7 classes.

# %%
validation_generator = validation_datagen.flow_from_directory(
							validation_data_dir,
							color_mode='grayscale',
							target_size=(IMG_HEIGHT, IMG_WIDTH),
							batch_size=batch_size,
							class_mode='categorical',
							shuffle=True)
# Out:
# Found 7178 images belonging to 7 classes.

# %%
class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']

img, label = train_generator.__next__()

# %%
import random 
i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
#now creating the model 
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(7, activation='softmax'))

model.compile(optimizer = 'adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# D:\anaconda\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 46, 46, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 44, 44, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 22, 22, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 22, 22, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 20, 20, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,489,095 (9.50 MB)
#  Trainable params: 2,489,095 (9.50 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
train_path = 'D:/jv/train'
test_path = 'D:/jv/test'

num_train_imgs = 0
for root, dirs, files in os.walk(train_path):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(test_path):
    num_test_imgs += len(files)

# %%
epochs=50
history=model.fit(train_generator,
                steps_per_epoch=num_train_imgs//batch_size,
                epochs=epochs,
                validation_data=validation_generator,
                validation_steps=num_test_imgs//batch_size)
model.save('emotion_detection_model_100epochs.h5')
# Out:
# Epoch 1/50
# D:\anaconda\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 117s 252ms/step - accuracy: 0.2448 - loss: 1.8155 - val_accuracy: 0.3295 - val_loss: 1.6686
# Epoch 2/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - accuracy: 0.2188 - loss: 1.7658 - val_accuracy: 0.4000 - val_loss: 1.6181
# Epoch 3/50
# D:\anaconda\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 109s 242ms/step - accuracy: 0.3103 - loss: 1.7004 - val_accuracy: 0.4325 - val_loss: 1.5022
# Epoch 4/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 237us/step - accuracy: 0.3906 - loss: 1.5618 - val_accuracy: 0.5000 - val_loss: 1.3598
# Epoch 5/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 105s 233ms/step - accuracy: 0.3866 - loss: 1.5563 - val_accuracy: 0.4840 - val_loss: 1.3470
# Epoch 6/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 125us/step - accuracy: 0.3594 - loss: 1.5319 - val_accuracy: 0.6000 - val_loss: 1.1821
# Epoch 7/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 105s 233ms/step - accuracy: 0.4387 - loss: 1.4474 - val_accuracy: 0.5071 - val_loss: 1.2869
# Epoch 8/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 143us/step - accuracy: 0.4844 - loss: 1.3450 - val_accuracy: 0.2000 - val_loss: 1.5722
# Epoch 9/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 106s 235ms/step - accuracy: 0.4733 - loss: 1.3741 - val_accuracy: 0.5361 - val_loss: 1.2183
# Epoch 10/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 152us/step - accuracy: 0.5781 - loss: 1.1094 - val_accuracy: 0.5000 - val_loss: 1.0996
# Epoch 11/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 105s 234ms/step - accuracy: 0.4959 - loss: 1.3247 - val_accuracy: 0.5220 - val_loss: 1.2402
# Epoch 12/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 130us/step - accuracy: 0.3750 - loss: 1.5673 - val_accuracy: 0.6000 - val_loss: 1.1787
# Epoch 13/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 106s 235ms/step - accuracy: 0.5079 - loss: 1.2851 - val_accuracy: 0.5607 - val_loss: 1.1510
# Epoch 14/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 143us/step - accuracy: 0.5469 - loss: 1.2011 - val_accuracy: 0.5000 - val_loss: 1.1014
# Epoch 15/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 106s 236ms/step - accuracy: 0.5135 - loss: 1.2662 - val_accuracy: 0.5639 - val_loss: 1.1370
# Epoch 16/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 144us/step - accuracy: 0.4688 - loss: 1.0731 - val_accuracy: 0.4000 - val_loss: 1.2296
# Epoch 17/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 105s 233ms/step - accuracy: 0.5264 - loss: 1.2410 - val_accuracy: 0.5682 - val_loss: 1.1305
# Epoch 18/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 134us/step - accuracy: 0.6094 - loss: 1.1372 - val_accuracy: 0.3000 - val_loss: 1.5643
# Epoch 19/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 105s 233ms/step - accuracy: 0.5392 - loss: 1.2160 - val_accuracy: 0.5744 - val_loss: 1.1125
# Epoch 20/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 143us/step - accuracy: 0.5469 - loss: 1.2834 - val_accuracy: 0.6000 - val_loss: 0.8577
# Epoch 21/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1610s 4s/step - accuracy: 0.5442 - loss: 1.2038 - val_accuracy: 0.5771 - val_loss: 1.1075
# Epoch 22/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 129us/step - accuracy: 0.5938 - loss: 1.0622 - val_accuracy: 0.6000 - val_loss: 1.0278
# Epoch 23/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 95s 211ms/step - accuracy: 0.5433 - loss: 1.2008 - val_accuracy: 0.5811 - val_loss: 1.1006
# Epoch 24/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 132us/step - accuracy: 0.4844 - loss: 1.1544 - val_accuracy: 0.5000 - val_loss: 1.1165
# Epoch 25/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 96s 214ms/step - accuracy: 0.5501 - loss: 1.1854 - val_accuracy: 0.5855 - val_loss: 1.1064
# Epoch 26/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 158us/step - accuracy: 0.5469 - loss: 1.3034 - val_accuracy: 0.6000 - val_loss: 0.9912
# Epoch 27/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 100s 221ms/step - accuracy: 0.5590 - loss: 1.1633 - val_accuracy: 0.5869 - val_loss: 1.0827
# Epoch 28/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 134us/step - accuracy: 0.5938 - loss: 1.1243 - val_accuracy: 0.7000 - val_loss: 0.6862
# Epoch 29/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 96s 213ms/step - accuracy: 0.5622 - loss: 1.1548 - val_accuracy: 0.5841 - val_loss: 1.0800
# Epoch 30/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 116us/step - accuracy: 0.5000 - loss: 1.3018 - val_accuracy: 0.7000 - val_loss: 0.8134
# Epoch 31/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 93s 207ms/step - accuracy: 0.5582 - loss: 1.1603 - val_accuracy: 0.5887 - val_loss: 1.0829
# Epoch 32/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 128us/step - accuracy: 0.6094 - loss: 1.1083 - val_accuracy: 0.7000 - val_loss: 0.6876
# Epoch 33/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 99s 221ms/step - accuracy: 0.5702 - loss: 1.1369 - val_accuracy: 0.5954 - val_loss: 1.0538
# Epoch 34/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 181us/step - accuracy: 0.6562 - loss: 1.2163 - val_accuracy: 0.5000 - val_loss: 1.4524
# Epoch 35/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 110s 243ms/step - accuracy: 0.5711 - loss: 1.1354 - val_accuracy: 0.6021 - val_loss: 1.0578
# Epoch 36/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 145us/step - accuracy: 0.5781 - loss: 1.0185 - val_accuracy: 0.8000 - val_loss: 0.6491
# Epoch 37/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 116s 257ms/step - accuracy: 0.5666 - loss: 1.1310 - val_accuracy: 0.6002 - val_loss: 1.0499
# Epoch 38/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 148us/step - accuracy: 0.6719 - loss: 1.0729 - val_accuracy: 0.4000 - val_loss: 1.7011
# Epoch 39/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 125s 277ms/step - accuracy: 0.5720 - loss: 1.1307 - val_accuracy: 0.6009 - val_loss: 1.0614
# Epoch 40/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 186us/step - accuracy: 0.5781 - loss: 1.1620 - val_accuracy: 0.5000 - val_loss: 1.2202
# Epoch 41/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 111s 247ms/step - accuracy: 0.5746 - loss: 1.1178 - val_accuracy: 0.6025 - val_loss: 1.0495
# Epoch 42/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 162us/step - accuracy: 0.5469 - loss: 0.9897 - val_accuracy: 0.4000 - val_loss: 1.2993
# Epoch 43/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 113s 249ms/step - accuracy: 0.5804 - loss: 1.1053 - val_accuracy: 0.6020 - val_loss: 1.0599
# Epoch 44/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 166us/step - accuracy: 0.5000 - loss: 1.1772 - val_accuracy: 0.6000 - val_loss: 0.9396
# Epoch 45/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 118s 263ms/step - accuracy: 0.5797 - loss: 1.1128 - val_accuracy: 0.6014 - val_loss: 1.0459
# Epoch 46/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 141us/step - accuracy: 0.6094 - loss: 1.0837 - val_accuracy: 0.7000 - val_loss: 0.9932
# Epoch 47/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 118s 262ms/step - accuracy: 0.5854 - loss: 1.0927 - val_accuracy: 0.6053 - val_loss: 1.0443
# Epoch 48/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 159us/step - accuracy: 0.6406 - loss: 1.0039 - val_accuracy: 0.6000 - val_loss: 0.8766
# Epoch 49/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 124s 276ms/step - accuracy: 0.5886 - loss: 1.0875 - val_accuracy: 0.6017 - val_loss: 1.0501
# Epoch 50/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 186us/step - accuracy: 0.7188 - loss: 0.9179 - val_accuracy: 0.4000 - val_loss: 1.5246
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# %%
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from keras.models import load_model
#testing model
my_model = load_model('emotion_detection_model_100epochs.h5', compile=False)

# %%
#Generating a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=my_model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Accuracy =  0.703125

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >

# %%
class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#we will check results on some images 
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
