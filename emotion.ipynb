# %%
import deeplake
ds = deeplake.load('hub://activeloop/fer2013-train')
# Out:
# |
# Opening dataset in read-only mode as you don't have write permissions.
# -
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/activeloop/fer2013-train
# -
# hub://activeloop/fer2013-train loaded successfully.

# %%
IMG_HEIGHT=48 
IMG_WIDTH = 48
batch_size=64

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
import os
from matplotlib import pyplot as plt
import numpy as np

# %%
train_data_dir='D:/jv/train'
validation_data_dir='D:/jv/test'

# %%
train_datagen = ImageDataGenerator(
					rescale=1./255,
					rotation_range=30,
					shear_range=0.3,
					zoom_range=0.3,
					horizontal_flip=True,
					fill_mode='nearest')

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
					train_data_dir,
					color_mode='grayscale',
					target_size=(IMG_HEIGHT, IMG_WIDTH),
					batch_size=batch_size,
					class_mode='categorical',
					shuffle=True)
# Out:
# Found 28709 images belonging to 7 classes.

# %%
validation_generator = validation_datagen.flow_from_directory(
							validation_data_dir,
							color_mode='grayscale',
							target_size=(IMG_HEIGHT, IMG_WIDTH),
							batch_size=batch_size,
							class_mode='categorical',
							shuffle=True)
# Out:
# Found 7178 images belonging to 7 classes.

# %%
class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']

img, label = train_generator.__next__()

# %%
import random 
i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
#now creating the model 
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(7, activation='softmax'))

model.compile(optimizer = 'adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# D:\anaconda\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 46, 46, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 44, 44, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 22, 22, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 22, 22, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 20, 20, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,489,095 (9.50 MB)
#  Trainable params: 2,489,095 (9.50 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
train_path = 'D:/jv/train'
test_path = 'D:/jv/test'

num_train_imgs = 0
for root, dirs, files in os.walk(train_path):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(test_path):
    num_test_imgs += len(files)

# %%
epochs=50
history=model.fit(train_generator,
                steps_per_epoch=num_train_imgs//batch_size,
                epochs=epochs,
                validation_data=validation_generator,
                validation_steps=num_test_imgs//batch_size)
model.save('emotion_detection_model_100epochs.h5')
# Out:
# Epoch 1/50
# D:\anaconda\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 115s 248ms/step - accuracy: 0.2504 - loss: 1.8068 - val_accuracy: 0.3435 - val_loss: 1.6720
# Epoch 2/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 282us/step - accuracy: 0.3281 - loss: 1.6353 - val_accuracy: 0.2000 - val_loss: 1.6565
# Epoch 3/50
# D:\anaconda\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 109s 243ms/step - accuracy: 0.3378 - loss: 1.6685 - val_accuracy: 0.4399 - val_loss: 1.4305
# Epoch 4/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 145us/step - accuracy: 0.4531 - loss: 1.4445 - val_accuracy: 0.4000 - val_loss: 1.2236
# Epoch 5/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 109s 241ms/step - accuracy: 0.4141 - loss: 1.5013 - val_accuracy: 0.5024 - val_loss: 1.3033
# Epoch 6/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 136us/step - accuracy: 0.4844 - loss: 1.3502 - val_accuracy: 0.2000 - val_loss: 1.5259
# Epoch 7/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 106s 236ms/step - accuracy: 0.4689 - loss: 1.3889 - val_accuracy: 0.5303 - val_loss: 1.2260
# Epoch 8/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 136us/step - accuracy: 0.5000 - loss: 1.3335 - val_accuracy: 0.7000 - val_loss: 0.8041
# Epoch 9/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 108s 241ms/step - accuracy: 0.4967 - loss: 1.3271 - val_accuracy: 0.5312 - val_loss: 1.2229
# Epoch 10/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 152us/step - accuracy: 0.5469 - loss: 1.3586 - val_accuracy: 0.5000 - val_loss: 1.3938
# Epoch 11/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 110s 244ms/step - accuracy: 0.5066 - loss: 1.2987 - val_accuracy: 0.5557 - val_loss: 1.1664
# Epoch 12/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 161us/step - accuracy: 0.5000 - loss: 1.2639 - val_accuracy: 0.8000 - val_loss: 0.8335
# Epoch 13/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 115s 255ms/step - accuracy: 0.5141 - loss: 1.2682 - val_accuracy: 0.5583 - val_loss: 1.1538
# Epoch 14/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 155us/step - accuracy: 0.5000 - loss: 1.3531 - val_accuracy: 0.4000 - val_loss: 1.2291
# Epoch 15/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 106s 235ms/step - accuracy: 0.5304 - loss: 1.2310 - val_accuracy: 0.5734 - val_loss: 1.1229
# Epoch 16/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 142us/step - accuracy: 0.6250 - loss: 1.1784 - val_accuracy: 0.4000 - val_loss: 1.7462
# Epoch 17/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 112s 249ms/step - accuracy: 0.5354 - loss: 1.2138 - val_accuracy: 0.5635 - val_loss: 1.1361
# Epoch 18/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 195us/step - accuracy: 0.5000 - loss: 1.1962 - val_accuracy: 0.7000 - val_loss: 1.1187
# Epoch 19/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 106s 236ms/step - accuracy: 0.5498 - loss: 1.1893 - val_accuracy: 0.5780 - val_loss: 1.1054
# Epoch 20/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 150us/step - accuracy: 0.7031 - loss: 0.8859 - val_accuracy: 0.8000 - val_loss: 0.7782
# Epoch 21/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 107s 237ms/step - accuracy: 0.5487 - loss: 1.1914 - val_accuracy: 0.5770 - val_loss: 1.1194
# Epoch 22/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 137us/step - accuracy: 0.5781 - loss: 1.1781 - val_accuracy: 0.3000 - val_loss: 1.4580
# Epoch 23/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 108s 239ms/step - accuracy: 0.5459 - loss: 1.1897 - val_accuracy: 0.5914 - val_loss: 1.0747
# Epoch 24/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 148us/step - accuracy: 0.6875 - loss: 1.0637 - val_accuracy: 0.5000 - val_loss: 1.6646
# Epoch 25/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 107s 237ms/step - accuracy: 0.5595 - loss: 1.1629 - val_accuracy: 0.5780 - val_loss: 1.1214
# Epoch 26/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 152us/step - accuracy: 0.5312 - loss: 1.2689 - val_accuracy: 0.6000 - val_loss: 1.0875
# Epoch 27/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 108s 240ms/step - accuracy: 0.5666 - loss: 1.1454 - val_accuracy: 0.5871 - val_loss: 1.0874
# Epoch 28/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 140us/step - accuracy: 0.6562 - loss: 1.1531 - val_accuracy: 0.4000 - val_loss: 1.4581
# Epoch 29/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 118s 262ms/step - accuracy: 0.5645 - loss: 1.1500 - val_accuracy: 0.5993 - val_loss: 1.0601
# Epoch 30/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 157us/step - accuracy: 0.6562 - loss: 1.0094 - val_accuracy: 0.5000 - val_loss: 1.4495
# Epoch 31/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 109s 243ms/step - accuracy: 0.5652 - loss: 1.1414 - val_accuracy: 0.5944 - val_loss: 1.0809
# Epoch 32/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 159us/step - accuracy: 0.5000 - loss: 1.2155 - val_accuracy: 0.6000 - val_loss: 0.9042
# Epoch 33/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 109s 243ms/step - accuracy: 0.5659 - loss: 1.1439 - val_accuracy: 0.5970 - val_loss: 1.0617
# Epoch 34/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 139us/step - accuracy: 0.5625 - loss: 1.2323 - val_accuracy: 0.5000 - val_loss: 1.7259
# Epoch 35/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 107s 239ms/step - accuracy: 0.5729 - loss: 1.1184 - val_accuracy: 0.6039 - val_loss: 1.0746
# Epoch 36/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 156us/step - accuracy: 0.6250 - loss: 0.8677 - val_accuracy: 0.4000 - val_loss: 1.6877
# Epoch 37/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 108s 241ms/step - accuracy: 0.5795 - loss: 1.1168 - val_accuracy: 0.6080 - val_loss: 1.0428
# Epoch 38/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 145us/step - accuracy: 0.5781 - loss: 1.0511 - val_accuracy: 0.5000 - val_loss: 0.9579
# Epoch 39/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 108s 240ms/step - accuracy: 0.5746 - loss: 1.1105 - val_accuracy: 0.6101 - val_loss: 1.0386
# Epoch 40/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 158us/step - accuracy: 0.5000 - loss: 1.1370 - val_accuracy: 0.7000 - val_loss: 1.2376
# Epoch 41/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 107s 238ms/step - accuracy: 0.5781 - loss: 1.1136 - val_accuracy: 0.6117 - val_loss: 1.0438
# Epoch 42/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 149us/step - accuracy: 0.5938 - loss: 1.0210 - val_accuracy: 0.6000 - val_loss: 1.1638
# Epoch 43/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 108s 241ms/step - accuracy: 0.5788 - loss: 1.1064 - val_accuracy: 0.6108 - val_loss: 1.0406
# Epoch 44/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 149us/step - accuracy: 0.5625 - loss: 1.1139 - val_accuracy: 0.5000 - val_loss: 1.0980
# Epoch 45/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 108s 241ms/step - accuracy: 0.5896 - loss: 1.0793 - val_accuracy: 0.6102 - val_loss: 1.0372
# Epoch 46/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 242us/step - accuracy: 0.3906 - loss: 1.6997 - val_accuracy: 0.7000 - val_loss: 0.9188
# Epoch 47/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 107s 238ms/step - accuracy: 0.5916 - loss: 1.0813 - val_accuracy: 0.6175 - val_loss: 1.0178
# Epoch 48/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 136us/step - accuracy: 0.4844 - loss: 1.2288 - val_accuracy: 0.6000 - val_loss: 1.3021
# Epoch 49/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 107s 237ms/step - accuracy: 0.5923 - loss: 1.0860 - val_accuracy: 0.6155 - val_loss: 1.0281
# Epoch 50/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 141us/step - accuracy: 0.6562 - loss: 0.8921 - val_accuracy: 0.6000 - val_loss: 0.8800
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# %%
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from keras.models import load_model
#testing model
my_model = load_model('emotion_detection_model_100epochs.h5', compile=False)

# %%
#Generating a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=my_model.predict(test_img)

predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Accuracy =  0.671875

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
#print(cm)
import seaborn as sns
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >
